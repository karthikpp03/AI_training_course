# %%
import os
import numpy as np
import pandas as pd
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from tensorflow.keras.optimizers import Adam

# %%
X = []
y = []

# %%
background_folder = r"D:\git\PRACTICE\DATA\level_1_train\level_1\background"
for file in os.listdir(background_folder):
    img_path = os.path.join(background_folder, file)
    img = load_img(img_path, target_size=(16,16), color_mode='grayscale')
    arr = img_to_array(img)/255.0
    X.append(arr)
    y.append(0)

# %%
text_folders = [
    r"D:\git\PRACTICE\DATA\level_1_train\level_1\en",
    r"D:\git\PRACTICE\DATA\level_1_train\level_1\hi",
    r"D:\git\PRACTICE\DATA\level_1_train\level_1\ta"
]

# %%
for folder in text_folders:
    for file in os.listdir(folder):
        img_path = os.path.join(folder, file)
        img = load_img(img_path, target_size=(16,16), color_mode='grayscale')
        arr = img_to_array(img)/255.0
        X.append(arr)
        y.append(1)

# %%
X = np.array(X)
y = np.array(y)

X = 1 - X

# %%
X = X.reshape(len(X), -1)
print("Training data shape:", X.shape, "Labels shape:", y.shape)
# Out:
# Training data shape: (892, 256) Labels shape: (892,)

# %%
X_test = []
test_ids = []

# %%
test_folder = r"D:\git\PRACTICE\DATA\level_1_test\kaggle_level_1"
for file in os.listdir(test_folder):
    img_path = os.path.join(test_folder, file)
    img = load_img(img_path, target_size=(16,16), color_mode='grayscale')
    arr = img_to_array(img)/255.0
    arr = 1 - arr  # invert
    X_test.append(arr)
    test_ids.append(int(file.split('.')[0]))

X_test = np.array(X_test).reshape(len(X_test), -1)
print("Test data shape:", X_test.shape)
# Out:
# Test data shape: (297, 256)

# %%
model = Sequential([
    Dense(128, input_shape=(256,), activation='relu'),
    Dense(64, activation='relu'),
    Dense(1, activation='sigmoid')  # output probability
])

model.compile(optimizer=Adam(0.001), loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# c:\Users\ERS1397\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 41,217 (161.00 KB)
#  Trainable params: 41,217 (161.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    X, y,
    epochs=50,
    batch_size=32,
    validation_split=0.1,  # optional
    verbose=2
)
# Out:
# Epoch 1/50
# 26/26 - 0s - 14ms/step - accuracy: 1.0000 - loss: 2.3591e-06 - val_accuracy: 1.0000 - val_loss: 8.8112e-13
# Epoch 2/50
# 26/26 - 0s - 13ms/step - accuracy: 1.0000 - loss: 2.3198e-06 - val_accuracy: 1.0000 - val_loss: 8.6050e-13
# Epoch 3/50
# 26/26 - 1s - 27ms/step - accuracy: 1.0000 - loss: 2.2813e-06 - val_accuracy: 1.0000 - val_loss: 8.3201e-13
# Epoch 4/50
# 26/26 - 0s - 13ms/step - accuracy: 1.0000 - loss: 2.2421e-06 - val_accuracy: 1.0000 - val_loss: 8.1850e-13
# Epoch 5/50
# 26/26 - 0s - 12ms/step - accuracy: 1.0000 - loss: 2.2045e-06 - val_accuracy: 1.0000 - val_loss: 7.8979e-13
# Epoch 6/50
# 26/26 - 0s - 14ms/step - accuracy: 1.0000 - loss: 2.1688e-06 - val_accuracy: 1.0000 - val_loss: 7.7553e-13
# Epoch 7/50
# 26/26 - 0s - 10ms/step - accuracy: 1.0000 - loss: 2.1330e-06 - val_accuracy: 1.0000 - val_loss: 7.5730e-13
# Epoch 8/50
# 26/26 - 0s - 12ms/step - accuracy: 1.0000 - loss: 2.0972e-06 - val_accuracy: 1.0000 - val_loss: 7.3389e-13
# Epoch 9/50
# 26/26 - 0s - 16ms/step - accuracy: 1.0000 - loss: 2.0620e-06 - val_accuracy: 1.0000 - val_loss: 7.2048e-13
# Epoch 10/50
# 26/26 - 0s - 15ms/step - accuracy: 1.0000 - loss: 2.0279e-06 - val_accuracy: 1.0000 - val_loss: 7.0854e-13
# Epoch 11/50
# 26/26 - 1s - 21ms/step - accuracy: 1.0000 - loss: 1.9945e-06 - val_accuracy: 1.0000 - val_loss: 6.8604e-13
# Epoch 12/50
# 26/26 - 1s - 21ms/step - accuracy: 1.0000 - loss: 1.9609e-06 - val_accuracy: 1.0000 - val_loss: 6.6519e-13
# Epoch 13/50
# 26/26 - 1s - 21ms/step - accuracy: 1.0000 - loss: 1.9283e-06 - val_accuracy: 1.0000 - val_loss: 6.5314e-13
# Epoch 14/50
# 26/26 - 1s - 20ms/step - accuracy: 1.0000 - loss: 1.8974e-06 - val_accuracy: 1.0000 - val_loss: 6.3392e-13
# Epoch 15/50
# 26/26 - 0s - 18ms/step - accuracy: 1.0000 - loss: 1.8666e-06 - val_accuracy: 1.0000 - val_loss: 6.1882e-13
# Epoch 16/50
# 26/26 - 0s - 15ms/step - accuracy: 1.0000 - loss: 1.8353e-06 - val_accuracy: 1.0000 - val_loss: 6.0329e-13
# Epoch 17/50
# 26/26 - 0s - 14ms/step - accuracy: 1.0000 - loss: 1.8046e-06 - val_accuracy: 1.0000 - val_loss: 5.9072e-13
# Epoch 18/50
# 26/26 - 0s - 15ms/step - accuracy: 1.0000 - loss: 1.7745e-06 - val_accuracy: 1.0000 - val_loss: 5.7794e-13
# Epoch 19/50
# 26/26 - 0s - 15ms/step - accuracy: 1.0000 - loss: 1.7459e-06 - val_accuracy: 1.0000 - val_loss: 5.6553e-13
# Epoch 20/50
# 26/26 - 0s - 15ms/step - accuracy: 1.0000 - loss: 1.7179e-06 - val_accuracy: 1.0000 - val_loss: 5.5143e-13
# Epoch 21/50
# 26/26 - 0s - 15ms/step - accuracy: 1.0000 - loss: 1.6902e-06 - val_accuracy: 1.0000 - val_loss: 5.3475e-13
# Epoch 22/50
# 26/26 - 0s - 16ms/step - accuracy: 1.0000 - loss: 1.6630e-06 - val_accuracy: 1.0000 - val_loss: 5.2143e-13
# Epoch 23/50
# 26/26 - 0s - 18ms/step - accuracy: 1.0000 - loss: 1.6365e-06 - val_accuracy: 1.0000 - val_loss: 5.1087e-13
# Epoch 24/50
# 26/26 - 0s - 17ms/step - accuracy: 1.0000 - loss: 1.6101e-06 - val_accuracy: 1.0000 - val_loss: 5.0173e-13
# Epoch 25/50
# 26/26 - 0s - 11ms/step - accuracy: 1.0000 - loss: 1.5838e-06 - val_accuracy: 1.0000 - val_loss: 4.8624e-13
# Epoch 26/50
# 26/26 - 0s - 12ms/step - accuracy: 1.0000 - loss: 1.5577e-06 - val_accuracy: 1.0000 - val_loss: 4.7622e-13
# Epoch 27/50
# 26/26 - 0s - 12ms/step - accuracy: 1.0000 - loss: 1.5325e-06 - val_accuracy: 1.0000 - val_loss: 4.6519e-13
# Epoch 28/50
# 26/26 - 0s - 10ms/step - accuracy: 1.0000 - loss: 1.5078e-06 - val_accuracy: 1.0000 - val_loss: 4.5274e-13
# Epoch 29/50
# 26/26 - 0s - 11ms/step - accuracy: 1.0000 - loss: 1.4838e-06 - val_accuracy: 1.0000 - val_loss: 4.4117e-13
# Epoch 30/50
# 26/26 - 0s - 11ms/step - accuracy: 1.0000 - loss: 1.4591e-06 - val_accuracy: 1.0000 - val_loss: 4.3269e-13
# Epoch 31/50
# 26/26 - 0s - 12ms/step - accuracy: 1.0000 - loss: 1.4356e-06 - val_accuracy: 1.0000 - val_loss: 4.2279e-13
# Epoch 32/50
# 26/26 - 0s - 13ms/step - accuracy: 1.0000 - loss: 1.4125e-06 - val_accuracy: 1.0000 - val_loss: 4.1446e-13
# Epoch 33/50
# 26/26 - 1s - 30ms/step - accuracy: 1.0000 - loss: 1.3903e-06 - val_accuracy: 1.0000 - val_loss: 4.0440e-13
# Epoch 34/50
# 26/26 - 0s - 8ms/step - accuracy: 1.0000 - loss: 1.3678e-06 - val_accuracy: 1.0000 - val_loss: 3.9264e-13
# Epoch 35/50
# 26/26 - 0s - 11ms/step - accuracy: 1.0000 - loss: 1.3459e-06 - val_accuracy: 1.0000 - val_loss: 3.8407e-13
# Epoch 36/50
# 26/26 - 0s - 12ms/step - accuracy: 1.0000 - loss: 1.3243e-06 - val_accuracy: 1.0000 - val_loss: 3.7781e-13
# Epoch 37/50
# 26/26 - 0s - 12ms/step - accuracy: 1.0000 - loss: 1.3032e-06 - val_accuracy: 1.0000 - val_loss: 3.6510e-13
# Epoch 38/50
# 26/26 - 0s - 13ms/step - accuracy: 1.0000 - loss: 1.2828e-06 - val_accuracy: 1.0000 - val_loss: 3.5962e-13
# Epoch 39/50
# 26/26 - 0s - 13ms/step - accuracy: 1.0000 - loss: 1.2621e-06 - val_accuracy: 1.0000 - val_loss: 3.4970e-13
# Epoch 40/50
# 26/26 - 0s - 11ms/step - accuracy: 1.0000 - loss: 1.2415e-06 - val_accuracy: 1.0000 - val_loss: 3.4209e-13
# Epoch 41/50
# 26/26 - 0s - 11ms/step - accuracy: 1.0000 - loss: 1.2215e-06 - val_accuracy: 1.0000 - val_loss: 3.3502e-13
# Epoch 42/50
# 26/26 - 0s - 18ms/step - accuracy: 1.0000 - loss: 1.2023e-06 - val_accuracy: 1.0000 - val_loss: 3.2663e-13
# Epoch 43/50
# 26/26 - 0s - 16ms/step - accuracy: 1.0000 - loss: 1.1830e-06 - val_accuracy: 1.0000 - val_loss: 3.1857e-13
# Epoch 44/50
# 26/26 - 0s - 11ms/step - accuracy: 1.0000 - loss: 1.1638e-06 - val_accuracy: 1.0000 - val_loss: 3.1141e-13
# Epoch 45/50
# 26/26 - 0s - 8ms/step - accuracy: 1.0000 - loss: 1.1453e-06 - val_accuracy: 1.0000 - val_loss: 3.0509e-13
# Epoch 46/50
# 26/26 - 0s - 13ms/step - accuracy: 1.0000 - loss: 1.1269e-06 - val_accuracy: 1.0000 - val_loss: 2.9845e-13
# Epoch 47/50
# 26/26 - 0s - 12ms/step - accuracy: 1.0000 - loss: 1.1085e-06 - val_accuracy: 1.0000 - val_loss: 2.9421e-13
# Epoch 48/50
# 26/26 - 0s - 11ms/step - accuracy: 1.0000 - loss: 1.0910e-06 - val_accuracy: 1.0000 - val_loss: 2.8593e-13
# Epoch 49/50
# 26/26 - 0s - 10ms/step - accuracy: 1.0000 - loss: 1.0733e-06 - val_accuracy: 1.0000 - val_loss: 2.7813e-13
# Epoch 50/50
# 26/26 - 0s - 12ms/step - accuracy: 1.0000 - loss: 1.0563e-06 - val_accuracy: 1.0000 - val_loss: 2.7236e-13

# %%
train_acc = history.history['accuracy'][-1]  
train_loss = history.history['loss'][-1]      

print(f"Final Training Accuracy: {train_acc:.4f}")
print(f"Final Training Loss: {train_loss:.4f}")
# Out:
# Final Training Accuracy: 1.0000
# Final Training Loss: 0.0000

# %%
y_pred_prob = model.predict(X_test).flatten() 
y_pred = (y_pred_prob > 0.5).astype(int)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
df = pd.DataFrame({
    'ImageId': test_ids,
    'Probability': y_pred_prob,
    'Class': y_pred_class
})
df.to_csv(r"D:\git\PRACTICE\DATA\OUTPUT\ffnn_predictions.csv", index=False)
print("Predictions saved to ffnn_predictions.csv")
# Out:
# Predictions saved to ffnn_predictions.csv

# %% [markdown]
# # Multi Class

# %%
X = []
y = []

background_folder = r"D:\git\PRACTICE\DATA\level_1_train\level_1\background"
for file in os.listdir(background_folder):
    img_path = os.path.join(background_folder, file)
    img = load_img(img_path, target_size=(16,16), color_mode='grayscale')
    arr = img_to_array(img)/255.0
    X.append(arr)
    y.append(0)

# %%
text_classes = {
    1: r"D:\git\PRACTICE\DATA\level_1_train\level_1\en",
    2: r"D:\git\PRACTICE\DATA\level_1_train\level_1\hi",
    3: r"D:\git\PRACTICE\DATA\level_1_train\level_1\ta"
}

# %%
for label, folder in text_classes.items():
    for file in os.listdir(folder):
        img_path = os.path.join(folder, file)
        img = load_img(img_path, target_size=(16,16), color_mode='grayscale')
        arr = img_to_array(img)/255.0
        X.append(arr)
        y.append(label)

# %%
X = np.array(X)
y = np.array(y)

X = 1 - X

# %%
X = X.reshape(len(X), -1)

y_cat = to_categorical(y, num_classes=4)

print("Training shape:", X.shape, "Labels shape:", y_cat.shape)

# %%
X_test = []
test_ids = []

# %%
test_folder = r"D:\git\PRACTICE\DATA\level_1_test\kaggle_level_1"
for file in os.listdir(test_folder):
    img_path = os.path.join(test_folder, file)
    img = load_img(img_path, target_size=(16,16), color_mode='grayscale')
    arr = img_to_array(img)/255.0
    arr = 1 - arr
    X_test.append(arr)
    test_ids.append(int(file.split('.')[0]))

X_test = np.array(X_test).reshape(len(X_test), -1)
print("Test shape:", X_test.shape)

# %%
model = Sequential([
    Dense(128, input_shape=(256,), activation='relu'),
    Dense(64, activation='relu'),
    Dense(4, activation='softmax')  # multi-class output
])

model.compile(optimizer=Adam(0.001), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()

# %%
model.fit(X, y_cat, epochs=100, batch_size=32, validation_split=0.1, verbose=2)

# %%
y_pred_prob = model.predict(X_test)
y_pred_class = np.argmax(y_pred_prob, axis=1)

# %%
df = pd.DataFrame({
    'ImageId': test_ids,
    'Class': y_pred_class
})
df.to_csv(r"D:\git\PRACTICE\DATA\OUTPUT\MULTI_ffnn_predictions.csv", index=False)
print("Predictions saved to ffnn_multiclass_predictions.csv")
